# %% [markdown]
# # 1. Install and import

# %% [markdown]
# Local execution using folders of the algorithm (don't need to use pip intall), change the path using sys.path.append

# %%
import sys
#FOLDER_PATH_EASYPLOT = r'G:\Meu Drive\006 - Biblioteca digital\006.000 - Algoritmos\EASYPLOTPYDEV\EASYPLOT_TOOLBOX'
FOLDER_PATH_EASYPLOT = '/home/nero/git-hub projects/EASYPLOTPYDEV/easyplot_toolbox/'
sys.path.append(FOLDER_PATH_EASYPLOT)

from easyplot import *
import pandas as pd
import numpy as np

# %% [markdown]
# Using pip install
#
# ```python
# pip install EASYPLOT-TOOLBOX
# from EASYPLOT_TOOLBOX import *
# import pandas as pd
# import numpy as np
# ```

# %% [markdown]
# # 2. Example 1

# %%
# Data
DF = pd.DataFrame({
    'group': ['SVM', 'ANN', 'FA', 'GA'],
    'score1': [38, 1.5, 30, 4],
    'score2': [29, 10, 9, 34],
    'score3': [8, 39, 23, 24],
    'score4': [17, 18, 45, 54]
})
   
# Chart setup
chart_config = {
    'name': 'Figure1-6-1',
    'width': 15, 
    'height': 15,
    'text size': 15,
    'div color': "blue",
    'radar color': ['#FF0000', 'magenta', 'black', 'blue'],
    'opacity': 0.05,
    'background': '#9FE2BF',
    'legend size': 12,
    'dots per inch': 600, 
    'extension': 'svg',
}


# Data statement 
DATA = {'dataset': DF}

# Call function
radar_chart(dataset = DATA, plot_setup = chart_config)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 30
#      27 DATA = {'dataset': DF}
#      29 # Call function
# ---> 30 radar_chart(dataset = DATA, plot_setup = chart_config)
#
# File ~/git-hub projects/EASYPLOTPYDEV/easyplot_toolbox/easyplot.py:601, in radar_chart(**kwargs)
#     599 categories = list(data)[1:]
#     600 n = len(categories)
# --> 601 angles = [n / float(n) * 2 * np.pi for n in range(n)]
#     602 angles += angles[:1]
#     603 ax.set_theta_offset(np.pi / 2)
#
# File ~/git-hub projects/EASYPLOTPYDEV/easyplot_toolbox/easyplot.py:601, in <listcomp>(.0)
#     599 categories = list(data)[1:]
#     600 n = len(categories)
# --> 601 angles = [n / float(n) * 2 * np.pi for n in range(n)]
#     602 angles += angles[:1]
#     603 ax.set_theta_offset(np.pi / 2)
#
# ZeroDivisionError: float division by zero
