# %% [markdown]
# # Install and import

# %% [markdown]
# Local execution using folders of the algorithm (don't need to use pip intall), change the path using sys.path.append

# %%
import sys
#FOLDER_PATH_EASYPLOT = r'G:\Meu Drive\006 - Biblioteca digital\006.000 - Algoritmos\EASYPLOTPYDEV\EASYPLOT_TOOLBOX'
FOLDER_PATH_EASYPLOT = '/home/nero/git-hub projects/EASYPLOTPYDEV/easyplot_toolbox/'
sys.path.append(FOLDER_PATH_EASYPLOT)

from easyplot import *
import random
import pandas as pd
import numpy as np

# %% [markdown]
# Using the easyplot toolbox package (**pip version**)

# %%
#pip install easyplot-toolbox
from easyplot_toolbox import *

# %% [markdown]
# # Example 1

# %%
# Data
DF = pd.DataFrame({ 'A1': [random.randint(1, 100) for _ in range(10)],
                    'A2': [random.randint(1, 100) for _ in range(10)],
                    'A3': [random.randint(1, 100) for _ in range(10)],
                    'A4': [random.randint(1, 100) for _ in range(10)],
                    'A5': [random.randint(1, 100) for _ in range(10)]
                  })

# Chart setup
plot_setup = {
    'name': 'figure1-7-1',
    'width': 30,
    'height': 15,
    'mask': False,
    'line widths': 8,
    'color map': 'plasma',
    'line color': 'white',
    'annot': True,
    'annot size font': 12,
    'dots per inch': 600,
    'extension': 'svg'
}


# Data statement 
DATA = {'dataset': DF}

# Call function
heatmap_chart(dataset = DATA, plot_setup = plot_setup)
