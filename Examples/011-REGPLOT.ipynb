# %% [markdown]
# # 1. Install and import

# %% [markdown]
# Local execution using folders of the algorithm (don't need to use pip intall), change the path using sys.path.append

# %%
import sys
# FOLDER_PATH_EASYPLOT = r'C:\Users\wande\Documents\EASYPLOTPYDEV\EASYPLOT_TOOLBOX'
FOLDER_PATH_EASYPLOT = '/home/nero/git-hub projects/EASYPLOTPYDEV/EASYPLOT_TOOLBOX/'
sys.path.append(FOLDER_PATH_EASYPLOT)

from EASYPLOT import *
import pandas as pd
import numpy as np

# %% [markdown]
# Using pip install
#
# ```python
# pip install EASYPLOT-TOOLBOX
# from EASYPLOT_TOOLBOX import *
# import pandas as pd
# import numpy as np
# ```

# %% [markdown]
# # 2. Example 1

# %%
# Data
HEIGHT = list(np.random.normal(165, 10, 2000))
WEIGHT = list(np.random.logistic(50, 4, 2000))
DF =  pd.DataFrame({'x': HEIGHT,
                    'y': WEIGHT,
                   })
    
# Chart setup
CHART_CONFIG = {
        'name': 'figure1-11-1',
        'width': 10,
        'height': 10,
        'marker size': 25,
        'SCATTER color': 'green',
        'line color': 'red',
        'ORDER': 1,
        'x axis label': 'Weight',
        'x axis size': 15,
        'y axis label': 'Height',
        'y axis size': 15,
        'axises color': 'red',
        'labels size': 15,
        'labels color': 'blue',
        'on grid?': False,
        'y log': False,
        'x log': False,
        'dots per inch': 600,
        'extension': 'svg',
    }


# Data statement 
DATA = {'dataset': DF}

# Call function
regplot_chart(dataset=DATA, plot_setup=CHART_CONFIG)
